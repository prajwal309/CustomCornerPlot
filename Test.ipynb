# %% [markdown]
# Import the basic libraries such as numpy and also the CornerPlot

# %%
#Load all the modules
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import CornerPlot


import logging
logging.captureWarnings('all')

# %% [markdown]
# Create a basic corner plot for fitting plot

# %%
Parameters = ["m","b"]
NumPoints = 10000
mValues = np.random.normal(2.34,0.1, NumPoints)
bValues = np.random.normal(5.56, 0.2, NumPoints)

Data2Plot = np.vstack((mValues, bValues))

CornerPlot.CustomCornerPlot(Data2Plot,Parameters)
# Out:
# m = 2.34$^{+0.10}_{-0.10}$
# b = 5.56$^{+0.20}_{-0.20}$

# %%
Parameters = ["m","b", "Offset"]
NumPoints = 10000

m1Values = np.random.normal(2.34,0.1, NumPoints)
b1Values = np.random.normal(5.56, 0.2, NumPoints)
Offset1Values = np.random.normal(106.55, 6.35, NumPoints)
Data1 = np.vstack((m1Values, b1Values,Offset1Values))

m2Values = np.random.normal(2.36,0.2, NumPoints)
b2Values = np.random.normal(6.59, 0.5, NumPoints)
Offset2Values = np.random.normal(100.25, 5.35, NumPoints)
Data2 = np.vstack((m2Values, b2Values, Offset2Values))


#CornerPlot.CustomCornerPlot(Data1,Parameters)
#CornerPlot.CustomCornerPlot(Data2,Parameters)
CornerPlot.DoubleCustomCornerPlot(Data1, Data2, Parameters)
# Out:
# m = 2.34$^{+0.10}_{-0.10}$
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# <ipython-input-5-cf38d79162c6> in <module>()
#      15 #CornerPlot.CustomCornerPlot(Data1,Parameters)
#      16 #CornerPlot.CustomCornerPlot(Data2,Parameters)
# ---> 17 CornerPlot.DoubleCustomCornerPlot(Data1, Data2, Parameters)
#
# /home/prajwal/Desktop/CustomCornerPlot/CornerPlot.py in DoubleCustomCornerPlot(Data1, Data2, Parameters)
#     166                 counts1,xbins1,ybins1=np.histogram2d(Data1[i,:], Data1[j,:],bins=NBins)
#     167                 counts2,xbins2,ybins2=np.histogram2d(Data2[i,:], Data2[j,:],bins=NBins)
# --> 168
#     169                 Levels1 = np.percentile(counts1,[68.27,95.45,99.73])
#     170                 Levels2 = np.percentile(counts2,[68.27,95.45,99.73])
#
# NameError: global name 'counts' is not defined
