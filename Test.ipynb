# %% [markdown]
# Import the basic libraries such as numpy and also the CornerPlot

# %%
#Load all the modules
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import CornerPlot


import logging
logging.captureWarnings('all')

# %% [markdown]
# Create a basic corner plot for fitting plot

# %%
Parameters = ["m","b"]
NumPoints = 10000
mValues = np.random.normal(2.34,0.1, NumPoints)
bValues = np.random.normal(5.56, 0.2, NumPoints)

Data2Plot = np.vstack((mValues, bValues))

CornerPlot.CustomCornerPlot(Data2Plot,Parameters)
# Out:
# m = 2.34$^{+0.10}_{-0.10}$
# b = 5.56$^{+0.20}_{-0.20}$

# %%
Parameters = ["m","b"]
NumPoints = 10000

m1Values = np.random.normal(2.34,0.1, NumPoints)
b1Values = np.random.normal(5.56, 0.2, NumPoints)
Data1 = np.vstack((m1Values, b1Values))

m2Values = np.random.normal(4.67,0.1, NumPoints)
b2Values = np.random.normal(9.56, 0.2, NumPoints)
Data2 = np.vstack((m2Values, b2Values))


CornerPlot.MultipleCustomCornerPlot(Data1,Data2, Parameters)
# Out:
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# <ipython-input-8-ebffb31cf30e> in <module>()
#      11
#      12
# ---> 13 CornerPlot.MultipleCustomCornerPlot(Data1,Data2, Parameters)
#
# /home/prajwal/Desktop/CustomCornerPlot/CornerPlot.py in MultipleCustomCornerPlot(Data1, Data2, Parameters)
#     201                 ax[i,j].hist(Data1[i,:], fill=False, histtype='step', linewidth=2, color="navy", normed=True)
#     202                 ax[i,j].hist(Data2[i,:], fill=False, histtype='step', linewidth=2, color="maroon", normed=True)
# --> 203                 PercentileValues = np.percentile(Data[i,:],[15.8, 50.0, 84.2])
#     204                 for counter_pc, Value in enumerate(PercentileValues):
#     205                     if counter_pc == 1:
#
# NameError: global name 'Data' is not defined
